# %%
f = open('wine.data', 'r')
import numpy as np
data = []
for line in f:
    row =[]
    line = line.strip('\n')
    for i in line.split(","):
        row.append(i)
    data.append(row)
dataMass = np.array(data)
print(np.shape(dataMass))
f.close()
# Out:
# (178, 14)

# %%
import pandas as pd
Columns = ["Type","Alcohol","Malic acid","Ash","Alcalinity of as","Magnesium","Total phenols","Flavanoids",
           "Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315","Proline"]
data = pd.DataFrame(data,columns = Columns)
data
# Out:
#     Type Alcohol Malic acid   Ash Alcalinity of as Magnesium Total phenols  \
# 0      1   14.23       1.71  2.43             15.6       127           2.8
# 1      1    13.2       1.78  2.14             11.2       100          2.65
# 2      1   13.16       2.36  2.67             18.6       101           2.8
# 3      1   14.37       1.95   2.5             16.8       113          3.85
# 4      1   13.24       2.59  2.87               21       118           2.8
# ..   ...     ...        ...   ...              ...       ...           ...
# 173    3   13.71       5.65  2.45             20.5        95          1.68
# 174    3    13.4       3.91  2.48               23       102           1.8
# 175    3   13.27       4.28  2.26               20       120          1.59
# 176    3   13.17       2.59  2.37               20       120          1.65
# 177    3   14.13        4.1  2.74             24.5        96          2.05
#
# ...

# %%
X = data[["Alcohol","Malic acid","Ash","Alcalinity of as","Magnesium","Total phenols","Flavanoids",
           "Nonflavanoid phenols","Proanthocyanins","Color intensity","Hue","OD280/OD315","Proline"]]
y = data["Type"]
y
import operator
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
result = {}
for i in range(1,51):
    kf = KFold(n_splits=5,shuffle=True,random_state=42)
    neigh = KNeighborsClassifier(n_neighbors=i)
    accuracy = cross_val_score(neigh, X,y, cv=kf)
    result[i]= sum(accuracy)/len(accuracy)
print(max(result.items(), key=operator.itemgetter(1))[0])   
print(result[max(result.items(), key=operator.itemgetter(1))[0]])
# Out:
# 1
# 0.7304761904761905

# %%
from sklearn.preprocessing import scale
X = scale(X,axis = 0)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
result = {}
for i in range(1,51):
    kf = KFold(n_splits=5,shuffle=True,random_state=42)
    neigh = KNeighborsClassifier(n_neighbors=i)
    accuracy = cross_val_score(neigh, X,y, cv=kf)
    result[i]= sum(accuracy)/len(accuracy)
    max(result.items(), key=operator.itemgetter(1))[0]
print(max(result.items(), key=operator.itemgetter(1))[0])  
print(result[max(result.items(), key=operator.itemgetter(1))[0]])
# Out:
# 29
# 0.9776190476190475
